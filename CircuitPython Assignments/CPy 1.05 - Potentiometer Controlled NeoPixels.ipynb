# %% [markdown]
# # CPy 1.05 - Potentiometer Controlled NeoPixels
# ___

# %% [markdown]
# ## Instructions
#
# Connect a potentiometer to the CPB per the supplied diagram. Use commands from `analogio` and `adafruit_circuitplayground` modules to control the brightness of all 10 NeoPixels. In your main loop read the value of the potentiometer and use the value to set the brightness of the NeoPixels. You will need to scale the potentiometer value from 0-65535 to 0-1 since the maximum brightness of the NeoPixels is 1. Use the color of your choice, but make all NeoPixels the same color.

# %% [markdown]
# ![CPB%20with%20Potentiometer.png](attachment:CPB%20with%20Potentiometer.png)

# %%
# Place your finised code here
